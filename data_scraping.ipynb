# %%
import yfinance as yf
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# Define Ticker
ticker_symbol = 'AAPL'
ticker = yf.Ticker(ticker_symbol)

# Get Option Expiration Dates
expiration_dates = ticker.options
expiration_dates

# Get Option Chain for a Specific Date
option_chain = ticker.option_chain(expiration_dates[0])
calls = option_chain.calls
calls.head()
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0  AAPL250718C00090000 2025-07-11 15:38:33+00:00    90.0     120.77  120.70
# 1  AAPL250718C00095000 2025-07-11 15:38:33+00:00    95.0     115.75  115.75
# 2  AAPL250718C00100000 2025-07-10 19:44:53+00:00   100.0     113.00  110.85
# 3  AAPL250718C00105000 2025-07-11 18:09:40+00:00   105.0     106.55  105.65
# 4  AAPL250718C00110000 2025-07-11 18:09:40+00:00   110.0     101.54  100.65
#
#       ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0  121.60 -2.230003      -1.813011     2.0           405           3.027346
# 1  116.65 -2.269997      -1.923400     2.0            13           2.109380
# 2  111.45  0.000000       0.000000     4.0           531           2.521488
# 3  106.65 -1.360001      -1.260310     3.0            43           2.569340
# 4  101.55 -1.370003      -1.331263    38.0           346           2.330082
#
#    inTheMoney contractSize currency
# 0        True      REGULAR      USD
# 1        True      REGULAR      USD
# 2        True      REGULAR      USD
# 3        True      REGULAR      USD
# 4        True      REGULAR      USD
